# %% [markdown]
# # Week 1: Navigation Circuits and Physiology
#
# This notebook introduces the neural circuits underlying spatial navigation.

# %%
import numpy as np
import matplotlib.pyplot as plt
